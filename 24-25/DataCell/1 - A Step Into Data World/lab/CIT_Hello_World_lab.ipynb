# %%
print("( 0 _ 0 )\n")
print("(•`_´•)\n")
print("( ╥﹏╥)")
# Out:
# ( 0 _ 0 )
#
# (•`_´•)
#
# ( ╥﹏╥)

# %%
import time

for i in range(5, 0, -1):
    print(f"Countdown: {i}...")
    time.sleep(1)
print("CIT a7ssan club! 👾")
# Out:
# Countdown: 5...
# Countdown: 4...
# Countdown: 3...
# Countdown: 2...
# Countdown: 1...
# CIT a7ssan club! 👾

# %%
import matplotlib.pyplot as plt


img = plt.imread("is_fortnite_overrated.jpg")
plt.title("Avg ASEDS conversation...")
plt.imshow(img)
plt.axis('off')
plt.show()
